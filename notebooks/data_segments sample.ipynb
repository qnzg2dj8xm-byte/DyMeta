# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/DynaMeta
# Out:
# /content/drive/MyDrive/DynaMeta

# %%
# !ls
# Out:
# checkpoints  data	README.md	  scripts
# configs      notebooks	requirements.txt  src

# %%
# !pip install pymatreader pyyaml hdbscan umap-learn scikit-learn pandas scipy
# Out:
# Requirement already satisfied: pymatreader in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.12/dist-packages (0.8.42)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.11)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from pymatreader) (3.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pymatreader) (2.0.2)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.12/dist-packages (from pymatreader) (1.0.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan) (1.5.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !python -m scripts.process_data
# Out:
# [INFO] 多模态数据预处理与特征提取流水线已启动。
#
# [INFO] 当前处理对象 (Subject ID): #1
#     -> [Loading] 正在解析原始多模态信号矩阵: part1
#     -> [Processing] 正在提取频域功率谱密度 (PSD) 与多模态表征特征...
#     -> [Success] 特征与标签张量已完成序列化，写入至: data/processed/#1
#
# [INFO] 当前处理对象 (Subject ID): #3
#     -> [Loading] 正在解析原始多模态信号矩阵: part1
#     -> [Processing] 正在提取频域功率谱密度 (PSD) 与多模态表征特征...
#     -> [Success] 特征与标签张量已完成序列化，写入至: data/processed/#3
#     -> [Loading] 正在解析原始多模态信号矩阵: part2
#     -> [Processing] 正在提取频域功率谱密度 (PSD) 与多模态表征特征...
#     -> [Success] 特征与标签张量已完成序列化，写入至: data/processed/#3
#
# [INFO] 当前处理对象 (Subject ID): #5
#     -> [Loading] 正在解析原始多模态信号矩阵: part1
#     -> [Processing] 正在提取频域功率谱密度 (PSD) 与多模态表征特征...
#     -> [Success] 特征与标签张量已完成序列化，写入至: data/processed/#5
#
# [INFO] 数据预处理流水线执行完毕。

# %%
# !python -m scripts.train
# Out:
# =================================================================
# [INFO] DynaMeta: Large-Scale Training Pipeline
# =================================================================
# [INFO] Compute Device: cuda
# [INFO] Training Subject IDs: ['#1', '#3']
# [INFO] Raw Training Set: Features (3456, 13), Labels (3456,)
# [INFO] Applying RobustScaler for feature normalization...
#   > Scaler fitted and saved to: checkpoints/feature_scaler.pkl
# [INFO] Dynamic focal loss pos_weight computed: 56.4500
#
# -----------------------------------------------------------------
# [INFO] Starting Large-Scale Training Iterations...
# -----------------------------------------------------------------
# Epoch [01/15] | Loss: 2.8732 (TBC:4.9282, Trans:0.2112) | Batch Acc: 55.5%
# Epoch [02/15] | Loss: 2.1692 (TBC:4.7462, Trans:0.1780) | Batch Acc: 83.6%
# Epoch [03/15] | Loss: 1.5422 (TBC:4.3834, Trans:0.1644) | Batch Acc: 96.9%
# Epoch [04/15] | Loss: 1.2916 (TBC:4.0455, Trans:0.1485) | Batch Acc: 95.3%
# Epoch [05/15] | Loss: 1.2053 (TBC:3.8868, Trans:0.1364) | Batch Acc: 96.9%
# Epoch [06/15] | Loss: 1.1575 (TBC:3.7865, Trans:0.1296) | Batch Acc: 96.9%
# Epoch [07/15] | Loss: 1.1251 (TBC:3.7126, Trans:0.1249) | Batch Acc: 93.0%
# Epoch [08/15] | Loss: 1.1192 (TBC:3.6739, Trans:0.1244) | Batch Acc: 95.3%
# Epoch [09/15] | Loss: 1.0877 (TBC:3.6035, Trans:0.1206) | Batch Acc: 96.1%
# Epoch [10/15] | Loss: 1.0479 (TBC:3.5815, Trans:0.1137) | Batch Acc: 95.3%
# Epoch [11/15] | Loss: 1.0297 (TBC:3.5547, Trans:0.1110) | Batch Acc: 99.2%
# Epoch [12/15] | Loss: 1.0099 (TBC:3.5170, Trans:0.1076) | Batch Acc: 97.7%
# Epoch [13/15] | Loss: 0.9940 (TBC:3.4895, Trans:0.1056) | Batch Acc: 98.4%
# Epoch [14/15] | Loss: 0.9639 (TBC:3.4672, Trans:0.1002) | Batch Acc: 98.4%
# Epoch [15/15] | Loss: 0.9408 (TBC:3.4430, Trans:0.0962) | Batch Acc: 96.9%
# -----------------------------------------------------------------
# [SUCCESS] Training Completed. Weights saved to: checkpoints/dynameta_best.pth
# =================================================================

# %%
# !python -m scripts.evaluate
# Out:
# =================================================================
# [INFO] DynaMeta: Evaluation Pipeline
# =================================================================
# [INFO] Test Set Loaded (#5): Features (1152, 13)
# [INFO] Applied fitted RobustScaler to test features.
# [INFO] Model Weights Loaded from: checkpoints/dynameta_best.pth
# [INFO] Running Full Forward Inference on Test Set...
#
# =================================================================
#  EVALUATION REPORT
# =================================================================
# Overall Accuracy: 99.48%
#
# Classification Report (Precision / Recall / F1-Score):
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#         NREM       0.99      1.00      1.00       695
#         Wake       1.00      0.99      0.99       448
#
#     accuracy                           0.99      1143
#    macro avg       1.00      0.99      0.99      1143
# weighted avg       0.99      0.99      0.99      1143
#
# =================================================================

# %%
# !python -m scripts.run_pipeline
# Out:
# =================================================================
# [INFO] DynaMeta: End-to-End Metacognitive Pipeline & MAM Dashboard
# =================================================================
# [INFO] Loading system configurations...
# [INFO] Mounting raw sandbox data from: data/raw/#5/part1
# [INFO] Extracting multimodal physiological features (PSD, EMG variance)...
# [INFO] Applied fitted RobustScaler to pipeline features successfully.
# [INFO] Generated test sequence tensor: torch.Size([1148, 5, 13])
# [INFO] Initializing DualMechanismNet...
# [INFO] Loaded trained weights from: checkpoints/dynameta_best.pth
# [INFO] Computing data-adaptive MAM thresholds from test distribution...
# [INFO] Loaded real prototypes from checkpoints.
#   > t_entropy (85th) set to: 0.5522
#   > t_dyn     (95th) set to: 0.0000
#   > t_dist    (99th) set to: 0.2413
# [INFO] Initializing CalibratedMetacognitiveLoop...
# [INFO] Executing forward inference and MAM routing...
# Dual-system streaming: 100% 5/5 [00:00<00:00, 53.27it/s]
#
# =================================================================
#   · Strategy D [Fast Pass]          :  1146 samples (99.83%)
#   · Strategy A [IG Feature Mask]    :     0 samples ( 0.00%)
#   · Strategy B [Transition Expand]  :     0 samples ( 0.00%)
#   · Strategy C [Cognitive Deferral] :     2 samples ( 0.17%)
# -----------------------------------------------------------------
# [SUCCESS] Pipeline streaming finished.
# =================================================================
